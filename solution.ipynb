# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Part A

# %%
train = pd.read_csv('train.csv')
train
# Out:
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 2 columns]

# %%
disasterTweets = train[train['target'] == 1]
disasterTweets
# Out:
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [3271 rows x 2 columns]

# %%
normalTweets = train[train['target'] == 0]
normalTweets
# Out:
#                                                    text  target
# 15                                       What's up man?       0
# 16                                        I love fruits       0
# 17                                     Summer is lovely       0
# 18                                    My car is so fast       0
# 19                         What a goooooooaaaaaal!!!!!!       0
# ...                                                 ...     ...
# 7581  @engineshed Great atmosphere at the British Li...       0
# 7582  Cramer: Iger's 3 words that wrecked Disney's s...       0
# 7584  These boxes are ready to explode! Exploding Ki...       0
# 7587                                 Sirens everywhere!       0
# 7593  I just heard a really loud bang and everyone i...       0
#
# [4342 rows x 2 columns]

# %%
import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')


lemmatizer = WordNetLemmatizer()

def lemmatize_words(words):
    lemmas = [lemmatizer.lemmatize(word) for word in words]
    return lemmas


disasterTweets['text'] = disasterTweets['text'].apply(lambda x: ' '.join(lemmatize_words(str(x).split())))

normalTweets['text'] = normalTweets['text'].apply(lambda x: ' '.join(lemmatize_words(str(x).split())))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <ipython-input-42-784bf1c89599>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disasterTweets['text'] = disasterTweets['text'].apply(lambda x: ' '.join(lemmatize_words(str(x).split())))
# <ipython-input-42-784bf1c89599>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalTweets['text'] = normalTweets['text'].apply(lambda x: ' '.join(lemmatize_words(str(x).split())))

# %%
from collections import Counter

disaster_word_freq = Counter(' '.join(disasterTweets['text']).split())

normal_word_freq = Counter(' '.join(normalTweets['text']).split())

# %%
disaster_top_words = disaster_word_freq.most_common(20)

normal_top_words = normal_word_freq.most_common(20)
print("Top 20 words by occurrence in disaster tweets")
print(disaster_top_words)
print("Top 20 words by occurrence in normal tweets")
print(normal_top_words)
# Out:
# Top 20 words by occurrence in disaster tweets
# [('the', 1051), ('in', 1037), ('of', 888), ('a', 869), ('to', 706), ('and', 462), ('-', 389), ('on', 386), ('for', 368), ('is', 302), ('at', 273), ('I', 259), ('The', 257), ('by', 244), ('from', 206), ('it', 170), ('A', 167), ('that', 166), ('fire', 161), ('with', 159)]
# Top 20 words by occurrence in normal tweets
# [('the', 1524), ('a', 1258), ('to', 1099), ('I', 938), ('and', 840), ('of', 834), ('in', 720), ('you', 529), ('is', 512), ('for', 452), ('my', 442), ('on', 387), ('-', 374), ('with', 349), ('that', 326), ('it', 325), ('The', 295), ('be', 268), ('like', 234), ('this', 225)]

# %%
import nltk
from nltk import ngrams

def get_ngrams(text, n=2):
    return [' '.join(ngram) for ngram in ngrams(text.split(), n)]


disasterTweets['bigrams'] = disasterTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=2)))

normalTweets['bigrams'] = normalTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=2)))

disasterTweets['trigrams'] = disasterTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=3)))

normalTweets['trigrams'] = normalTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=3)))
# Out:
# <ipython-input-45-8fd65bdf950a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disasterTweets['bigrams'] = disasterTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=2)))
# <ipython-input-45-8fd65bdf950a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalTweets['bigrams'] = normalTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=2)))
# <ipython-input-45-8fd65bdf950a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disasterTweets['trigrams'] = disasterTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=3)))
# <ipython-input-45-8fd65bdf950a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalTweets['trigrams'] = normalTweets['text'].apply(lambda x: ' '.join(get_ngrams(x, n=3)))

# %%
disaster_bigram_freq = Counter(' '.join(disasterTweets['bigrams']).split())
normal_bigram_freq = Counter(' '.join(normalTweets['bigrams']).split())


disaster_top_bigrams = disaster_bigram_freq.most_common(20)
print('Top 20 bigrams by occurrence in disaster tweets')
print(disaster_top_bigrams)

normal_top_bigrams = normal_bigram_freq.most_common(20)
print('Top 20 bigrams by occurrence in normal tweets')
print(normal_top_bigrams)

disaster_trigram_freq = Counter(' '.join(disasterTweets['trigrams']).split())
normal_trigram_freq = Counter(' '.join(normalTweets['trigrams']).split())


disaster_top_trigrams = disaster_trigram_freq.most_common(20)
print('Top 20 trigrams by occurrence in disaster tweets')
print(disaster_top_trigrams)

normal_top_trigrams = normal_trigram_freq.most_common(20)
print('Top 20 trigrams by occurrence in normal tweets')
print(normal_top_trigrams)
# Out:
# Top 20 bigrams by occurrence in disaster tweets
# [('the', 2098), ('in', 2073), ('of', 1776), ('a', 1737), ('to', 1412), ('and', 922), ('-', 778), ('on', 771), ('for', 735), ('is', 604), ('at', 546), ('by', 487), ('I', 464), ('from', 412), ('The', 403), ('it', 333), ('that', 328), ('with', 318), ('fire', 317), ('wa', 316)]
# Top 20 bigrams by occurrence in normal tweets
# [('the', 3032), ('a', 2514), ('to', 2196), ('and', 1675), ('of', 1667), ('I', 1657), ('in', 1435), ('you', 1046), ('is', 1024), ('for', 902), ('my', 878), ('on', 772), ('-', 744), ('with', 697), ('that', 644), ('it', 631), ('be', 536), ('The', 489), ('like', 464), ('by', 450)]
# Top 20 trigrams by occurrence in disaster tweets
# [('the', 3061), ('in', 3057), ('of', 2607), ('a', 2534), ('to', 2056), ('and', 1348), ('on', 1119), ('-', 1116), ('for', 1082), ('is', 871), ('at', 803), ('by', 720), ('I', 643), ('from', 598), ('The', 536), ('that', 480), ('it', 469), ('with', 464), ('wa', 458), ('fire', 450)]
# Top 20 trigrams by occurrence in normal tweets
# [('the', 4376), ('a', 3662), ('to', 3215), ('and', 2449), ('of', 2436), ('I', 2257), ('in', 2094), ('you', 1461), ('is', 1431), ('for', 1306), ('my', 1244), ('on', 1119), ('-', 1066), ('with', 1020), ('that', 932), ('it', 897), ('be', 775), ('like', 667), ('The', 660), ('by', 658)]

# %% [markdown]
# # Part B

# %%
import re
import string
import nltk
nltk.download('stopwords')

def preprocess_text(text):
    text = text.translate(str.maketrans('', '', string.punctuation))

    text = re.sub(r'@\w+', '', text)

    tokens = nltk.word_tokenize(text)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [token for token in tokens if token.casefold() not in stop_words]
    text = ' '.join(tokens)

    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
disasterTweets['text'] = disasterTweets['text'].apply(preprocess_text)
normalTweets['text'] = normalTweets['text'].apply(preprocess_text)
disasterTweets
# Out:
# <ipython-input-49-2807337cb6c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disasterTweets['text'] = disasterTweets['text'].apply(preprocess_text)
# <ipython-input-49-2807337cb6c9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalTweets['text'] = normalTweets['text'].apply(preprocess_text)
#                                                    text  target  \
# 0           Deeds Reason earthquake May ALLAH Forgive u       1
# 1                 Forest fire near La Ronge Sask Canada       1
# 2     resident asked shelter place notified officers...       1
# 3     13000 people receive wildfires evacuation orde...       1
# 4     got sent photo Ruby Alaska smoke wildfires pou...       1
# ...                                                 ...     ...
# 7608  Two giant crane holding bridge collapse nearby...       1
# 7609  ariaahrary TheTawniest control wild fire Calif...       1
# 7610  M194 0104 UTC5km Volcano Hawaii httptcozDtoyd8EbJ       1
# 7611  Police investigating ebike collided car Little...       1
# 7612  Latest Homes Razed Northern California Wildfir...       1
#
#                                                 bigrams  \
# 0     Our Deeds Deeds are are the the Reason Reason ...
# 1     Forest fire fire near near La La Ronge Ronge S...
# 2     All resident resident asked asked to to 'shelt...
# 3     13,000 people people receive receive #wildfire...
# 4     Just got got sent sent this this photo photo f...
# ...                                                 ...
# 7608  Two giant giant crane crane holding holding a ...
# 7609  @aria_ahrary @TheTawniest @TheTawniest The The...
# 7610  M1.94 [01:04 [01:04 UTC]?5km UTC]?5km S S of o...
# 7611  Police investigating investigating after after...
# 7612  The Latest: Latest: More More Homes Homes Raze...
#
#                                                trigrams
# 0     Our Deeds are Deeds are the are the Reason the...
# 1     Forest fire near fire near La near La Ronge La...
# 2     All resident asked resident asked to asked to ...
# 3     13,000 people receive people receive #wildfire...
# 4     Just got sent got sent this sent this photo th...
# ...                                                 ...
# 7608  Two giant crane giant crane holding crane hold...
# 7609  @aria_ahrary @TheTawniest The @TheTawniest The...
# 7610  M1.94 [01:04 UTC]?5km [01:04 UTC]?5km S UTC]?5...
# 7611  Police investigating after investigating after...
# 7612  The Latest: More Latest: More Homes More Homes...
#
# [3271 rows x 4 columns]

# %% [markdown]
# # Part C

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score


tweets = pd.concat([disasterTweets['text'], normalTweets['text']], axis=0)

vectorizer1 = CountVectorizer(max_features=100)
vectorizer2 = CountVectorizer(max_features=1000)

X1 = vectorizer1.fit_transform(tweets)
X2 = vectorizer2.fit_transform(tweets)

y = np.concatenate([np.ones(len(disasterTweets)), np.zeros(len(normalTweets))], axis=0)

clf1 = LogisticRegression()
clf1.fit(X1, y)

clf2 = LogisticRegression()
clf2.fit(X2, y)


y_pred1 = clf1.predict(X1)
y_pred2 = clf2.predict(X2)


acc1 = accuracy_score(y, y_pred1)
f1_1 = f1_score(y, y_pred1)
rec1 = recall_score(y, y_pred1)

acc2 = accuracy_score(y, y_pred2)
f1_2 = f1_score(y, y_pred2)
rec2 = recall_score(y, y_pred2)


print("Results for max_features=100:")
print("Accuracy:", acc1)
print("F1 score:", f1_1)
print("Recall:", rec1)

print("\nResults for max_features=1000:")
print("Accuracy:", acc2)
print("F1 score:", f1_2)
print("Recall:", rec2)
# Out:
# Results for max_features=100:
# Accuracy: 0.7148298962301327
# F1 score: 0.601724454228582
# Recall: 0.5013757260776521
#
# Results for max_features=1000:
# Accuracy: 0.842637593589912
# F1 score: 0.8047588005215124
# Recall: 0.7548150412717823
